# %%
import argparse
from tqdm import tqdm

from predpatt import PredPatt
from predpatt import load_conllu

# %%
conll_example = [ud_parse for sent_id, ud_parse in load_conllu('/workspace/data/users/zanchangtong1/3_XIE/data/En-Zh/all.conllu.clean.En')][0]
print(conll_example.pprint(K=3))

# %%
pp = PredPatt.from_sentence('Chris loves silly dogs and clever cats .')
print(pp.pprint())

# %%
i = list(range(100))
print(i[1:])

# %% [markdown]
# ## ACE05 experiments

# %%
import json

file_path = '/workspace/data/users/zanchangtong1/3_XIE/Tools/ACE05-Processor/processed-data/English/train/AFP_ENG_20030304.0250.v1.json'
file = open(file_path, 'r', encoding='utf-8')
a = json.load(file)
print(a)
# Out:
# {'entities': [{'entity-id': 'AFP_ENG_20030304.0250-E1-3', 'entity-type': 'ORG:Medical-Science', 'text': 'The Davao Medical Center', 'position': [493, 516], 'head': {'text': 'Davao Medical Center', 'position': [497, 516]}}, {'entity-id': 'AFP_ENG_20030304.0250-E1-4', 'entity-type': 'ORG:Medical-Science', 'text': 'a regional government hospital', 'position': [519, 548], 'head': {'text': 'hospital', 'position': [541, 548]}}, {'entity-id': 'AFP_ENG_20030304.0250-E3-5', 'entity-type': 'GPE:Nation', 'text': 'government', 'position': [530, 539], 'head': {'text': 'government', 'position': [530, 539]}}, {'entity-id': 'AFP_ENG_20030304.0250-E3-27', 'entity-type': 'GPE:Nation', 'text': 'Philippines', 'position': [153, 163], 'head': {'text': 'Philippines', 'position': [153, 163]}}, {'entity-id': 'AFP_ENG_20030304.0250-E4-6', 'entity-type': 'PER:Group', 'text': '50', 'position': [575, 576], 'head': {'text': '50', 'position': [575, 576]}}, {'entity-id': 'AFP_ENG_20030304.0250-E5-7', 'entity-type':
# ...
